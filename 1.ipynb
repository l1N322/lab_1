# %% [markdown]
# # Практическое задание №1
#
# **Жирный текст**, *курсив*
#
# ## Нумерованный список
# <ol>
#     <li>Первый пунтк</li>
#     <li>Второй пунтк</li>
#     <li>Третий пунтк</li>
# </ol>
#
# ## Маркированный список
#
# <ul>
#     <li>Первый</li>
#     <li>Второй</li>
#     <li>Третий</li>
#         <ul>
#             <li>Подэлемент</li>
#         </ul
# </ul>
#
# ## Формула для вычисления собственных значений матрицы:
#
# $|A - λE|$, где E - единичная матрица того же размера, что А
#
# ## Изображение:
#
# ![Человек-паук](data:image/jpeg;base64,...)

# %%
name = input("Введите ваше имя: ")

print(f"Привет, {name}. Добро пожаловать в JupyterLab!")
# Out:
# Введите ваше имя:  Данил
# Привет, Данил. Добро пожаловать в JupyterLab!
